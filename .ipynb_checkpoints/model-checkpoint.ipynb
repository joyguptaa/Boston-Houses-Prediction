# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### ```To check if is there any null value?```

# %%
def is_there_null(df):
    
    '''Return those columns which are having any null values along with frequency in a dictionary format'''
    
    null_values = list(df.isnull().sum())
    columns = df.columns
    
    null_values = {columns[i] : null_values[i] for i in range(len(columns)) if null_values[i] != 0}
    return null_values

# %% [markdown]
# ### ``` Drop un-useful columns```

# %%
def drop_columns(df, columns):
    df.drop(columns = columns_to_drop, inplace = True)
    return df

# %% [markdown]
# ### ``` Label Encoding & Filling NaN values```

# %%
def alteration1(df, null_values):
    '''This function either converts the dtype from object to category for label encoding or fill the null values of other dtype'''
   
    for column in df.columns:  
        
        if df[column].dtype == "object":
            df[column] = df[column].astype("category") #Converting dype
            df[column] = df[column].cat.codes  # Label Encoding
            
        elif df[column].isnull().any(): # if any null value exist
            df[column].fillna(value = round(df[column].mean()), inplace = True) #fill it with mean value
            del null_values[column] #And remove it from record
    return df, null_values

# %%
def alteration2(df, null_values):
    '''Label Encoding made all null values from object data column equals to -1'''
    for key in null_values.keys():
        df.loc[df[key] == -1, key] = round(df[key].mean())
    return df

# %% [markdown]
# # Data Visualization

# %%
def Correlation_matrix(df):
    import seaborn as sns
    data_correlation = df.corr()
    plt.figure(figsize = (30, 30))
    sns.heatmap(data_correlation, cmap = "Blues")
    plt.show()

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### ``` Circular Disc Plot```

# %%
def CircularDisc(score):
    plt.figure(figsize = (20,10))
    plt.style.use("seaborn")
    plt.pie(x = score['score'][:10], labels = score['feature'][:10] , autopct = '%1.1f%%')
    plt.plot();

# %% [markdown]
# ### ```Histogram Plot```

# %%
def Histogram(score):
    plt.figure(figsize = (40, 20))
    plt.style.use("seaborn")
    plt.xlabel("Feature Name")
    plt.ylabel("Score")
    plt.bar(score["feature"][:23], score["score"][:23], color = ["orange", "blue"])
    plt.show()

# %% [markdown]
# ### ``` Applying Selectkbest ```

# %%
def feature_selection(df):
    # Separating X and Y from Data frame
    X = df.iloc[:,:-1]
    Y = df.iloc[:, -1]
    
    best_features = SelectKBest(score_func = chi2, k = 20) # Object Instantiation
    best_fit = best_features.fit(X, Y)
    
    dfscores = pd.DataFrame(best_fit.scores_)
    dfbest = pd.DataFrame(X.columns)
    
    # Now concatenate them with scores
    feature_score = pd.concat([dfbest, dfscores], axis = 1)
    feature_score.columns = ["feature", "score"]
    
    feature_score.sort_values(by = "score", ascending = False, inplace = True)
    CircularDisc(feature_score)
    Histogram(feature_score)
    
    
    feature_score.reset_index(drop = True, inplace = True)
    return feature_score

# %% [markdown]
# ## Load Training Data

# %%
df_train = pd.read_csv("./dataset/Train_Data.csv")
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ```checking if there's null value in training dataset```

# %%
train_null = is_there_null(df_train)
for key, value in train_null.items():
    print("{} column have {} null values\n".format(key, value))
# Out:
# LotFrontage column have 192 null values
#
# Alley column have 1031 null values
#
# MasVnrType column have 6 null values
#
# MasVnrArea column have 6 null values
#
# BsmtQual column have 31 null values
#
# BsmtCond column have 31 null values
#
# BsmtExposure column have 32 null values
#
# BsmtFinType1 column have 31 null values
#
# BsmtFinType2 column have 32 null values
#
# FireplaceQu column have 524 null values
#
# GarageType column have 61 null values
#
# GarageYrBlt column have 61 null values
#
# GarageFinish column have 61 null values
#
# GarageQual column have 61 null values
#
# GarageCond column have 61 null values
#
# PoolQC column have 1098 null values
#
# Fence column have 892 null values
#
# MiscFeature column have 1054 null values

# %%
columns_to_drop = ["Id", "Alley", "Fence", "FireplaceQu", "MiscFeature", "PoolQC"] # These columns are having maximum no of null values

# %% [markdown]
# ```Dropping some columns from training data```

# %%
df_train = drop_columns(df_train, columns_to_drop)
df_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
# Now again check how many columns are still left with null values
train_null = is_there_null(df_train)
for key, value in train_null.items():
    print("{} column have {} null values\n".format(key, value))
# Out:
# LotFrontage column have 192 null values
#
# MasVnrType column have 6 null values
#
# MasVnrArea column have 6 null values
#
# BsmtQual column have 31 null values
#
# BsmtCond column have 31 null values
#
# BsmtExposure column have 32 null values
#
# BsmtFinType1 column have 31 null values
#
# BsmtFinType2 column have 32 null values
#
# GarageType column have 61 null values
#
# GarageYrBlt column have 61 null values
#
# GarageFinish column have 61 null values
#
# GarageQual column have 61 null values
#
# GarageCond column have 61 null values

# %% [markdown]
# ``` Label Encoding and Filling some NaN values```

# %%
df_train, train_null = alteration1(df_train, train_null)

# %%
df_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0          0          4          0  ...              0          0
# 1          0          2          0  ...              0          0
# 2          0          4          0  ...              0          0
# 3          0          0          0  ...            272          0
# 4          0          2          0  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %% [markdown]
# ``` Removing those converted null values to -1```

# %%
df_train = alteration2(df_train, train_null)
df_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0          0          4          0  ...              0          0
# 1          0          2          0  ...              0          0
# 2          0          4          0  ...              0          0
# 3          0          0          0  ...            272          0
# 4          0          2          0  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
feature_score = feature_selection(df_train)

# %%
feature_score
# Out:
#          feature         score
# 0        LotArea  1.027535e+07
# 1        MiscVal  6.212954e+06
# 2       2ndFlrSF  3.862425e+05
# 3     BsmtFinSF1  3.227511e+05
# 4     BsmtFinSF2  3.118325e+05
# ..           ...           ...
# 69  KitchenAbvGr  2.634932e+01
# 70    GarageCond  2.490213e+01
# 71    Condition2  1.825097e+01
# 72        Street  2.656012e+00
# 73        YrSold  5.078610e-01
#
# [74 rows x 2 columns]

# %% [markdown]
# ## ```Select some top and bottom features```

# %%
gonna_be_features = list(feature_score.loc[:20, "feature"])
gonna_be_features.extend(list(feature_score.loc[65:, "feature"]))

# %%
x_train = df_train.loc[:][gonna_be_features]
y_train = df_train.loc[:]["SalePrice"]

# %%
x_train.head()
# Out:
#    LotArea  MiscVal  2ndFlrSF  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  MasVnrArea  \
# 0     8450        0       854         706           0        150       196.0
# 1     9600        0         0         978           0        284         0.0
# 2    11250        0       866         486           0        434       162.0
# 3     9550        0       756         216           0        540         0.0
# 4    14260        0      1053         655           0        490       350.0
#
#    LowQualFinSF  3SsnPorch  PoolArea  ...  RoofMatl  ExterCond  PavedDrive  \
# 0             0          0         0  ...         0          4           2
# 1             0          0         0  ...         0          4           2
# 2             0          0         0  ...         0          4           2
# 3             0          0         0  ...         0          4           2
# 4             0          0         0  ...         0          4           2
#
# ...

# %%
y_train.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
x_train.shape, y_train.shape
# Out:
# ((1100, 30), (1100,))

# %% [markdown]
# Now the ```Training Data``` is completely cleaned. It is time to apply ANN Algorithm

# %% [markdown]
# # Building a Multilayer Perceptron Network

# %%
x_train = x_train.values
y_train = y_train.values

x_train.shape, y_train.shape
# Out:
# ((1100, 30), (1100,))

# %% [markdown]
# ### Model -1

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes = (32, 16, 16), activation = "relu", solver = "adam", max_iter = 500)
mlp.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(32, 16, 16), max_iter=500)

# %%
y_predict_train = mlp.predict(x_train)
